# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from joblib import Parallel, delayed
import random


from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier

import hw3_main
from helper import *

random.seed(69)

# %% [markdown]
# ## Load Data

# %%
X_challenge, y_challenge, X_heldout, feature_names = local_get_challenge_data()
# Out:
# Loading files from disk:   0%|                                                                                                                               | 0/12000 [00:00<?, ?it/s]
#
#
# Loading files from disk:   1%|▉                                                                                                                    | 98/12000 [00:00<00:13, 902.67it/s]
#
#
# Loading files from disk:   2%|█▉                                                                                                                  | 194/12000 [00:00<00:12, 927.51it/s]
#
#
# Loading files from disk:   2%|██▊                                                                                                                 | 287/12000 [00:00<00:12, 919.35it/s]
#
#
# Loading files from disk:   3%|███▋                                                                                                                | 379/12000 [00:00<00:13, 842.73it/s]
#
#
# Loading files from disk:   4%|████▌                                                                                                               | 467/12000 [00:00<00:13, 854.31it/s]
#
#
# Loading files from disk:   5%|█████▎                                                                                                              | 556/12000 [00:00<00:13, 865.66it/s]
#
#
# Loading files from disk:   5%|██████▎                                                                                                             | 655/12000 [00:00<00:12, 904.04it/s]
#
#
# Loading files from disk:   6%|███████▏                                                                                                            | 746/12000 [00:00<00:12, 904.62it/s]
#
#
# Loading files from disk:   7%|████████                                                                                                            | 837/12000 [00:00<00:12, 906.04it/s]
#
#
# Loading files from disk:   8%|████████▉                                                                                                           | 928/12000 [00:01<00:12, 902.83it/s]
#
#
# Loading files from disk:   8%|█████████▊                                                                                                         | 1019/12000 [00:01<00:12, 870.58it/s]
#
#
# Loading files from disk:   9%|██████████▌                                                                                                        | 1107/12000 [00:01<00:12, 862.11it/s]
#
#
# Loading files from disk:  10%|███████████▍                                                                                                       | 1195/12000 [00:01<00:12, 866.28it/s]
#
#
# Loading files from disk:  11%|████████████▎                                                                                                      | 1282/12000 [00:01<00:12, 837.28it/s]
#
#
# Loading files from disk:  11%|█████████████                                                                                                      | 1366/12000 [00:01<00:12, 832.74it/s]
#
#
# Loading files from disk:  12%|██████████████                                                                                                     | 1472/12000 [00:01<00:11, 882.75it/s]
#
#
# Loading files from disk:  13%|███████████████                                                                                                    | 1578/12000 [00:01<00:11, 895.34it/s]
#
#
# Loading files from disk:  14%|████████████████                                                                                                   | 1670/12000 [00:01<00:11, 901.26it/s]
#
#
# Loading files from disk:  15%|████████████████▉                                                                                                  | 1773/12000 [00:01<00:10, 938.09it/s]
#
#
# Loading files from disk:  16%|██████████████████                                                                                                 | 1884/12000 [00:02<00:10, 946.08it/s]
#
#
# Loading files from disk:  16%|██████████████████▉                                                                                                | 1979/12000 [00:02<00:11, 899.25it/s]
#
#
# Loading files from disk:  17%|███████████████████▊                                                                                               | 2072/12000 [00:02<00:11, 901.15it/s]
#
#
# Loading files from disk:  18%|████████████████████▉                                                                                              | 2188/12000 [00:02<00:10, 940.99it/s]
#
#
# Loading files from disk:  19%|█████████████████████▉                                                                                             | 2285/12000 [00:02<00:10, 946.46it/s]
#
#
# Loading files from disk:  20%|███████████████████████                                                                                            | 2402/12000 [00:02<00:09, 967.77it/s]
#
#
# Loading files from disk:  21%|███████████████████████▉                                                                                           | 2499/12000 [00:02<00:10, 926.73it/s]
#
#
# Loading files from disk:  22%|████████████████████████▊                                                                                          | 2592/12000 [00:02<00:10, 924.20it/s]
#
#
# Loading files from disk:  22%|█████████████████████████▊                                                                                         | 2690/12000 [00:02<00:09, 939.41it/s]
#
#
# Loading files from disk:  23%|██████████████████████████▊                                                                                        | 2804/12000 [00:03<00:09, 954.27it/s]
#
#
# Loading files from disk:  24%|███████████████████████████▊                                                                                       | 2906/12000 [00:03<00:09, 969.30it/s]
#
#
# Loading files from disk:  25%|████████████████████████████▉                                                                                      | 3022/12000 [00:03<00:09, 982.85it/s]
#
#
# Loading files from disk:  26%|█████████████████████████████▉                                                                                     | 3121/12000 [00:03<00:09, 946.04it/s]
#
#
# Loading files from disk:  27%|██████████████████████████████▊                                                                                    | 3217/12000 [00:03<00:09, 937.06it/s]
#
#
# Loading files from disk:  28%|███████████████████████████████▊                                                                                   | 3318/12000 [00:03<00:09, 933.38it/s]
#
#
# Loading files from disk:  29%|████████████████████████████████▊                                                                                  | 3425/12000 [00:03<00:08, 954.02it/s]
#
#
# Loading files from disk:  29%|█████████████████████████████████▋                                                                                 | 3521/12000 [00:03<00:08, 950.64it/s]
#
#
# Loading files from disk:  30%|██████████████████████████████████▋                                                                                | 3617/12000 [00:03<00:08, 952.42it/s]
#
#
# Loading files from disk:  31%|███████████████████████████████████▌                                                                               | 3713/12000 [00:04<00:08, 954.24it/s]
#
#
# Loading files from disk:  32%|████████████████████████████████████▋                                                                              | 3825/12000 [00:04<00:08, 958.70it/s]
#
#
# Loading files from disk:  33%|█████████████████████████████████████▌                                                                             | 3921/12000 [00:04<00:08, 958.12it/s]
#
#
# Loading files from disk:  34%|██████████████████████████████████████▌                                                                            | 4022/12000 [00:04<00:08, 972.46it/s]
# Loading files from disk:  34%|███████████████████████████████████████▍                                                                           | 4120/12000 [00:04<00:08, 973.76it/s]
#
#
# Loading files from disk:  35%|████████████████████████████████████████▍                                                                          | 4218/12000 [00:04<00:07, 974.80it/s]
#
#
# Loading files from disk:  36%|█████████████████████████████████████████▎                                                                         | 4316/12000 [00:04<00:07, 975.90it/s]
#
#
# Loading files from disk:  37%|██████████████████████████████████████████▎                                                                        | 4414/12000 [00:04<00:07, 973.59it/s]
#
#
# Loading files from disk:  38%|███████████████████████████████████████████▎                                                                       | 4520/12000 [00:04<00:07, 957.38it/s]
#
#
# Loading files from disk:  38%|████████████████████████████████████████████▏                                                                      | 4617/12000 [00:04<00:07, 960.93it/s]
#
#
# Loading files from disk:  39%|█████████████████████████████████████████████▏                                                                     | 4714/12000 [00:05<00:07, 963.29it/s]
#
#
# Loading files from disk:  40%|██████████████████████████████████████████████▎                                                                    | 4827/12000 [00:05<00:07, 968.11it/s]
#
#
# Loading files from disk:  41%|███████████████████████████████████████████████▏                                                                   | 4924/12000 [00:05<00:07, 931.00it/s]
#
#
# Loading files from disk:  42%|████████████████████████████████████████████████                                                                   | 5018/12000 [00:05<00:07, 921.36it/s]
#
#
# Generating feature vectors:   0%|▎                                                                                                               | 31/12000 [04:39<29:58:40,  9.02s/it]
#
#
#
# Loading files from disk:  43%|█████████████████████████████████████████████████▉                                                                 | 5209/12000 [00:06<00:27, 244.10it/s]
#
#
# Loading files from disk:  44%|███████████████████████████████████████████████████                                                                | 5327/12000 [00:06<00:19, 333.76it/s]
#
#
# Loading files from disk:  45%|███████████████████████████████████████████████████▊                                                               | 5408/12000 [00:06<00:16, 389.99it/s]
#
#
# Loading files from disk:  46%|████████████████████████████████████████████████████▋                                                              | 5502/12000 [00:06<00:13, 466.92it/s]
#
#
# Loading files from disk:  47%|█████████████████████████████████████████████████████▋                                                             | 5608/12000 [00:07<00:11, 569.38it/s]
#
#
# Loading files from disk:  48%|██████████████████████████████████████████████████████▉                                                            | 5731/12000 [00:07<00:09, 682.99it/s]
#
#
# Loading files from disk:  49%|███████████████████████████████████████████████████████▉                                                           | 5841/12000 [00:07<00:07, 772.80it/s]
#
#
# Loading files from disk:  50%|████████████████████████████████████████████████████████▉                                                          | 5941/12000 [00:07<00:07, 825.71it/s]
#
#
# Loading files from disk:  50%|█████████████████████████████████████████████████████████▉                                                         | 6041/12000 [00:07<00:07, 797.06it/s]
#
#
# Loading files from disk:  51%|██████████████████████████████████████████████████████████▊                                                        | 6133/12000 [00:07<00:07, 826.67it/s]
#
#
# Loading files from disk:  52%|███████████████████████████████████████████████████████████▊                                                       | 6239/12000 [00:07<00:06, 852.78it/s]
#
#
# Loading files from disk:  53%|████████████████████████████████████████████████████████████▊                                                      | 6346/12000 [00:07<00:06, 906.91it/s]
#
#
# Loading files from disk:  54%|█████████████████████████████████████████████████████████████▉                                                     | 6458/12000 [00:07<00:05, 926.20it/s]
#
#
# Loading files from disk:  55%|██████████████████████████████████████████████████████████████▊                                                    | 6559/12000 [00:07<00:05, 946.18it/s]
#
#
# Loading files from disk:  56%|████████████████████████████████████████████████████████████████                                                   | 6686/12000 [00:08<00:05, 993.47it/s]
#
#
# Loading files from disk:  57%|█████████████████████████████████████████████████████████████████                                                  | 6788/12000 [00:08<00:05, 998.04it/s]
#
#
# Loading files from disk:  57%|█████████████████████████████████████████████████████████████████▍                                                | 6890/12000 [00:08<00:05, 1004.16it/s]
#
#
# Loading files from disk:  58%|██████████████████████████████████████████████████████████████████▍                                               | 6992/12000 [00:08<00:04, 1006.34it/s]
#
#
# Loading files from disk:  59%|███████████████████████████████████████████████████████████████████▉                                               | 7094/12000 [00:08<00:05, 965.84it/s]
#
#
# Loading files from disk:  60%|████████████████████████████████████████████████████████████████████▉                                              | 7198/12000 [00:08<00:05, 946.19it/s]
#
#
# Loading files from disk:  61%|█████████████████████████████████████████████████████████████████████▉                                             | 7297/12000 [00:08<00:04, 957.78it/s]
#
#
# Loading files from disk:  62%|██████████████████████████████████████████████████████████████████████▉                                            | 7398/12000 [00:08<00:04, 970.30it/s]
#
#
# Loading files from disk:  63%|███████████████████████████████████████████████████████████████████████▉                                           | 7511/12000 [00:08<00:04, 974.33it/s]
#
#
# Loading files from disk:  63%|████████████████████████████████████████████████████████████████████████▉                                          | 7611/12000 [00:09<00:04, 973.77it/s]
#
#
# Loading files from disk:  64%|██████████████████████████████████████████████████████████████████████████                                         | 7730/12000 [00:09<00:04, 992.46it/s]
#
#
# Loading files from disk:  65%|███████████████████████████████████████████████████████████████████████████                                        | 7830/12000 [00:09<00:04, 993.08it/s]
#
#
# Loading files from disk:  66%|███████████████████████████████████████████████████████████████████████████▉                                       | 7930/12000 [00:09<00:04, 992.55it/s]
#
#
# Loading files from disk:  67%|████████████████████████████████████████████████████████████████████████████▉                                      | 8030/12000 [00:09<00:03, 994.51it/s]
#
#
# Loading files from disk:  68%|█████████████████████████████████████████████████████████████████████████████▉                                     | 8130/12000 [00:09<00:04, 954.33it/s]
#
#
# Loading files from disk:  69%|██████████████████████████████████████████████████████████████████████████████▊                                    | 8227/12000 [00:09<00:03, 956.73it/s]
#
#
# Loading files from disk:  69%|███████████████████████████████████████████████████████████████████████████████▊                                   | 8329/12000 [00:09<00:03, 968.84it/s]
# Loading files from disk:  70%|████████████████████████████████████████████████████████████████████████████████▉                                  | 8445/12000 [00:09<00:03, 985.80it/s]
#
#
# Loading files from disk:  71%|█████████████████████████████████████████████████████████████████████████████████▉                                 | 8544/12000 [00:10<00:03, 942.62it/s]
#
#
# Loading files from disk:  72%|██████████████████████████████████████████████████████████████████████████████████▊                                | 8639/12000 [00:10<00:03, 937.82it/s]
#
#
# Loading files from disk:  73%|███████████████████████████████████████████████████████████████████████████████████▋                               | 8738/12000 [00:10<00:03, 951.92it/s]
#
#
# Loading files from disk:  74%|████████████████████████████████████████████████████████████████████████████████████▋                              | 8834/12000 [00:10<00:03, 953.96it/s]
#
#
# Loading files from disk:  74%|█████████████████████████████████████████████████████████████████████████████████████▌                             | 8930/12000 [00:10<00:03, 874.44it/s]
#
#
# Loading files from disk:  75%|██████████████████████████████████████████████████████████████████████████████████████▍                            | 9019/12000 [00:10<00:03, 876.94it/s]
#
#
# Loading files from disk:  76%|███████████████████████████████████████████████████████████████████████████████████████▌                           | 9135/12000 [00:10<00:03, 916.85it/s]
#
#
# Loading files from disk:  77%|████████████████████████████████████████████████████████████████████████████████████████▍                          | 9234/12000 [00:10<00:02, 937.15it/s]
#
#
# Loading files from disk:  78%|█████████████████████████████████████████████████████████████████████████████████████████▍                         | 9329/12000 [00:10<00:02, 900.22it/s]
#
#
# Loading files from disk:  79%|██████████████████████████████████████████████████████████████████████████████████████████▎                        | 9422/12000 [00:10<00:02, 906.79it/s]
#
#
# Loading files from disk:  79%|███████████████████████████████████████████████████████████████████████████████████████████▎                       | 9532/12000 [00:11<00:02, 921.02it/s]
#
#
# Loading files from disk:  80%|████████████████████████████████████████████████████████████████████████████████████████████▍                      | 9641/12000 [00:11<00:02, 965.42it/s]
#
#
# Loading files from disk:  81%|█████████████████████████████████████████████████████████████████████████████████████████████▎                     | 9741/12000 [00:11<00:02, 974.89it/s]
#
#
# Loading files from disk:  82%|█████████████████████████████████████████████████████████████████████████████████████████████▌                    | 9850/12000 [00:11<00:02, 1008.20it/s]
#
#
# Loading files from disk:  83%|██████████████████████████████████████████████████████████████████████████████████████████████▌                   | 9952/12000 [00:11<00:02, 1009.60it/s]
#
#
# Loading files from disk:  84%|███████████████████████████████████████████████████████████████████████████████████████████████▌                  | 10054/12000 [00:11<00:01, 988.06it/s]
#
#
# Loading files from disk:  85%|████████████████████████████████████████████████████████████████████████████████████████████████▍                 | 10154/12000 [00:11<00:01, 970.86it/s]
#
#
# Loading files from disk:  86%|█████████████████████████████████████████████████████████████████████████████████████████████████▌                | 10266/12000 [00:11<00:01, 993.91it/s]
#
#
# Loading files from disk:  86%|██████████████████████████████████████████████████████████████████████████████████████████████████▍               | 10366/12000 [00:11<00:01, 995.34it/s]
#
#
# Loading files from disk:  87%|███████████████████████████████████████████████████████████████████████████████████████████████████▍              | 10466/12000 [00:12<00:01, 996.09it/s]
#
#
# Loading files from disk:  88%|████████████████████████████████████████████████████████████████████████████████████████████████████▍             | 10566/12000 [00:12<00:01, 997.21it/s]
#
#
# Loading files from disk:  89%|█████████████████████████████████████████████████████████████████████████████████████████████████████▎            | 10666/12000 [00:12<00:01, 997.93it/s]
#
#
# Loading files from disk:  90%|██████████████████████████████████████████████████████████████████████████████████████████████████████▎           | 10766/12000 [00:12<00:01, 997.88it/s]
#
#
# Loading files from disk:  91%|███████████████████████████████████████████████████████████████████████████████████████████████████████▏          | 10866/12000 [00:12<00:01, 998.12it/s]
#
#
# Loading files from disk:  91%|████████████████████████████████████████████████████████████████████████████████████████████████████████▏         | 10966/12000 [00:12<00:01, 954.30it/s]
#
#
# Loading files from disk:  92%|█████████████████████████████████████████████████████████████████████████████████████████████████████████▏        | 11070/12000 [00:12<00:00, 978.85it/s]
#
#
# Loading files from disk:  93%|█████████████████████████████████████████████████████████████████████████████████████████████████████████▎       | 11178/12000 [00:12<00:00, 1007.28it/s]
#
#
# Loading files from disk:  94%|██████████████████████████████████████████████████████████████████████████████████████████████████████████▏      | 11280/12000 [00:12<00:00, 1010.78it/s]
#
#
# Loading files from disk:  95%|████████████████████████████████████████████████████████████████████████████████████████████████████████████▏     | 11382/12000 [00:12<00:00, 953.02it/s]
#
#
# Loading files from disk:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████     | 11479/12000 [00:13<00:00, 945.76it/s]
#
#
# Loading files from disk:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████▉    | 11575/12000 [00:13<00:00, 945.53it/s]
#
#
# Loading files from disk:  97%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████▊   | 11670/12000 [00:13<00:00, 909.55it/s]
#
#
# Loading files from disk:  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████▋  | 11762/12000 [00:13<00:00, 910.34it/s]
#
#
# Loading files from disk:  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌ | 11854/12000 [00:13<00:00, 912.77it/s]
#
#
# Loading files from disk: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12000/12000 [00:13<00:00, 879.67it/s]
# Generating feature vectors: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12000/12000 [04:56<00:00, 40.42it/s]

# %% [markdown]
# ## Exploration

# %%
len(feature_names)
# Out:
# 75

# %% [markdown]
# Seeing if we should one-hot encode any categorical variables by looking at the number of unique values in each column:

# %%
df = make_df(X_challenge, feature_names)
print(df.columns[df.nunique() <= 5])
# Out:
# Index(['Gender', 'ICUType'], dtype='object')

# %% [markdown]
# As we can see, these 2 variables have less than 5 unique observations. We can make them into one-hot encoded variables.

# %% [markdown]
# ## Setup

# %%
def make_df(X, names):
    assert X.shape[1] == len(names)

    tmp = dict()
    for i, k in enumerate(names):
        tmp[k] = X[:, i]
    return pd.DataFrame(tmp)

# %%
def local_generate_feature_vector_challenge(df):
    static_variables = config['static']
    timeseries_variables = config['timeseries']
    feature_dict = {}
    
    for var in static_variables:
        val = df[df["Variable"] == var]["Value"].values[0]
        feature_dict[var] = val

        if val < 0:
            feature_dict[var] = np.nan
        else:
            feature_dict[var] = val
    
        # Time-varying variables
    for var in timeseries_variables:
        if (df['Variable'] == var).sum() == 0:
            fval = np.nan
            sval = np.nan
            norm_sd = np.nan
        else:
            fval = (df[(df["Variable"] == var) & (df["Time"].str[:2].astype(int) < 24)]["Value"]).mean()
            sval = (df[(df["Variable"] == var) & (df["Time"].str[:2].astype(int) >= 24)]["Value"]).mean()
            sd = (df[(df["Variable"] == var)]["Value"]).std()
            mean = (df[(df["Variable"] == var)]["Value"]).mean()
            norm_sd = sd/mean
            
        feature_dict[f"f24_mean_{var}"] = fval
        feature_dict[f"s24_mean_{var}"] = sval
        feature_dict[f"norm_sd_{var}"] = norm_sd
    
    return feature_dict

# local_generate_feature_vector_challenge(df)

# %%
def local_get_challenge_data():
    """
    This function is similar to helper.get_train_test_split, except that:
    - It reads in all 10,000 training examples
    - It does not return labels for the 2,000 examples in the heldout test set
    You should replace your preprocessing functions (generate_feature_vector,
    impute_missing_values, normalize_feature_matrix) with updated versions for the challenge
    """


    df_labels = pd.read_csv('data/labels.csv')
    df_labels = df_labels
    IDs = df_labels['RecordID']
    raw_data = {}
    for i in tqdm(IDs, desc='Loading files from disk'):
        raw_data[i] = pd.read_csv('data/files/{}.csv'.format(i))

    features = Parallel(n_jobs=16)(delayed(local_generate_feature_vector_challenge)(df) for _, df in tqdm(raw_data.items(), desc='Generating feature vectors'))
    df_features = pd.DataFrame(features)
    df_features = pd.get_dummies(df_features, columns=["Gender", "ICUType"])
    
    feature_names = df_features.columns.tolist()
    
    X, y = df_features.values, df_labels['30-day_mortality'].values
#     X = hw3_challenge.impute_missing_values_challenge(X)
#     X = hw3_challenge.normalize_feature_matrix_challenge(X)
    return X[:10000], y[:10000], X[10000:], feature_names

# %%
def impute_missing_values_challenge(X):
    return hw3_main.impute_missing_values(X)

# %%
def normalize_feature_matrix_challenge(X):
    return hw3_main.normalize_feature_matrix(X)

# %%
def get_train_val_split(X: np.ndarray[float], y: np.ndarray[int]):
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.20, stratify=y, random_state=69)
    return X_train, X_val, y_train, y_val

# %%
def preprocess(X: np.ndarray[float], feature_names):
    df = make_df(X, feature_names)
    
    

    df_new = pd.get_dummies(df, columns=['Gender', 'ICUType'])
    df_new.rename(columns={
        'Gender_0.0': 'gender_0',
        'Gender_0.5611444778111445': 'gender_1',
        'Gender_1.0': 'gender_2',
        'ICUType_0.0': 'CCU',
        'ICUType_0.3333333333333333': 'CSRU',
        'ICUType_0.6666666666666666': 'MedICU',
        'ICUType_1.0': 'SurgICU'
    }, inplace=True)
    print(df_new.columns)

    X_new = X
    feature_names_new = feature_names

    

    return X_new, feature_names_new

# %%
def run_challenge(X_challenge, y_challenge, X_heldout, feature_names):
    X_cha, feat_names = preprocess(X_challenge, feature_names)
    # clf = LogisticRegression()
    # clf.fit(X_challenge, y_challenge)

    # X_train, X_val, y_train, y_val = get_train_val_split(X_challenge, y_challenge)
    # assert X_train.shape[0] == y_train.size and X_val.shape[0] == y_val.size


    # C_range = np.logspace(-4, 4, 9)

    # y_score = clf.predict_proba(X_heldout)[:, 1]
    # y_label = clf.predict(X_heldout)
    # make_challenge_submission(y_label, y_score)
run_challenge(X_challenge, y_challenge, X_heldout, feature_names)
# Out:
# Index(['Age', 'Height', 'Weight', 'mean_ALP', 'mean_ALT', 'mean_AST',
#        'mean_Albumin', 'mean_BUN', 'mean_Bilirubin', 'mean_Cholesterol',
#        'mean_Creatinine', 'mean_DiasABP', 'mean_FiO2', 'mean_GCS',
#        'mean_Glucose', 'mean_HCO3', 'mean_HCT', 'mean_HR', 'mean_K',
#        'mean_Lactate', 'mean_MAP', 'mean_Mg', 'mean_NIDiasABP', 'mean_NIMAP',
#        'mean_NISysABP', 'mean_Na', 'mean_PaCO2', 'mean_PaO2', 'mean_Platelets',
#        'mean_RespRate', 'mean_SaO2', 'mean_SysABP', 'mean_Temp',
#        'mean_TroponinI', 'mean_TroponinT', 'mean_Urine', 'mean_WBC', 'mean_pH',
#        'gender_0', 'gender_1', 'gender_2', 'CCU', 'CSRU', 'MedICU', 'SurgICU'],
#       dtype='object')
# Generating feature vectors:  38%|███████████████████████████████████████████▏                                                                     | 4592/12000 [01:27<01:49, 67.87it/s]

# %% [markdown]
# ## Running

# %%
run_challenge(X_challenge, y_challenge, X_heldout, feature_names)
test_challenge_output()
# Out:
# Loading files from disk: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12000/12000 [00:05<00:00, 2093.39it/s]
# Generating feature vectors: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12000/12000 [00:07<00:00, 1505.91it/s]
# ================= Part 3 ===================
# Part 3: Challenge
# Saving challenge output...
# challenge.csv saved
# SUCCESS: csv file is valid.
